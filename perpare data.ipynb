# %%
import numpy as np
import os
import random
import shutil
import cv2

import matplotlib.pyplot as plt
from natsort import natsorted
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ## Collect Data
#
# from two folders with different sub-folders

# %%
train1_dataset_path = "data/train_Images_Source_1/"
train2_dataset_path = "data/train_Images_Source_2/"

# %%
dataset = []
for category in os.listdir(train1_dataset_path):
    category_path = os.path.join(train1_dataset_path, category)
    if os.path.isdir(category_path):
        for image_file in os.listdir(category_path):
            image_path = os.path.join(category_path, image_file)
            dataset.append((image_path, category))

# %%
for image_file in os.listdir(train2_dataset_path):
    category = image_file.split('_')[0]
    image_path = os.path.join(train2_dataset_path, image_file)
    dataset.append((image_path, category))

# %%
random.shuffle(dataset)

# %% [markdown]
# after loading data from different paths it's time to save it!

# %%
all_train ="data/dataset"

for image_path, category in dataset:
    category_folder = os.path.join(all_train, category)
    os.makedirs(category_folder, exist_ok=True)
    shutil.copy(image_path, category_folder)

# %% [markdown]
# ### Data Splitting

# %%
train_ratio = 0.8
train_size = int(len(dataset) * train_ratio)

train_dataset = dataset[:train_size]
val_dataset = dataset[train_size:]

# %%
train_folder = 'data/train_set'
val_folder = 'data/val_set'

for image_path, category in train_dataset:
    category_folder = os.path.join(train_folder, category)
    os.makedirs(category_folder, exist_ok=True)
    shutil.copy(image_path, category_folder)

for image_path, category in val_dataset:
    category_folder = os.path.join(val_folder, category)
    os.makedirs(category_folder, exist_ok=True)
    shutil.copy(image_path, category_folder)

# %% [markdown]
# ## Data Over-sampling

# %%
def load_and_augment_image(image_path, datagen):
    img = load_image(image_path)
    if img is not None:
        img = datagen.random_transform(img)
    return img

def load_image(image_path):
    try:
        img = cv2.imread(image_path)
        if img is not None:
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        return img
    except Exception as e:
        print(f"Error loading image {image_path}: {str(e)}")
        return None

def save_image(img, path):
    try:
        img_bgr = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
        cv2.imwrite(path, img_bgr)
        print(f"Saved image to {path}")
    except Exception as e:
        print(f"Error saving image to {path}: {str(e)}")

# %%
dataset_path = 'data/dataset'

target_num_images = max([len(files) for root, dirs, files in os.walk(dataset_path)])

datagen = ImageDataGenerator(
    rotation_range=20,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

# %%
for class_folder in os.listdir(dataset_path):
    class_folder_path = os.path.join(dataset_path, class_folder)
    
    num_images = len(os.listdir(class_folder_path))
    
    num_additional_images = target_num_images - num_images
    
    if num_additional_images > 0:
        print(f'Class {class_folder} needs {num_additional_images} additional images.')
        
        augmented_folder = os.path.join(class_folder_path, 'augmented')
        os.makedirs(augmented_folder, exist_ok=True)
        
        while num_additional_images > 0:
            random_image = random.choice(os.listdir(class_folder_path))
            image_path = os.path.join(class_folder_path, random_image)
            
            img = load_and_augment_image(image_path, datagen)
            
            augmented_image_path = os.path.join(augmented_folder, f'augmented_{num_additional_images}.jpg')
            save_image(img, augmented_image_path)
            
            num_additional_images -= 1

print('Oversampling completed!')
# Out:
# Class Ascariasis needs 754 additional images.
# Saved image to data/dataset\Ascariasis\augmented\augmented_754.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented
jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_114.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_113.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_112.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_111.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_110.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_109.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_108.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_107.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_106.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_105.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_104.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_103.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_102.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_101.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_100.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_99.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_98.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_97.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_96.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_95.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_94.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_93.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_92.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_91.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_90.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_89.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_88.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_87.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_86.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_85.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_84.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_83.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_82.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_81.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_80.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_79.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_78.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_77.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_76.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_75.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_74.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_73.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_72.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_71.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_70.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_69.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_68.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_67.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_66.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_65.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_64.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_63.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_62.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_61.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_60.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_59.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_58.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_57.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_56.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_55.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_54.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_53.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_52.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_51.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_50.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_49.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_48.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_47.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_46.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_45.jpg
# Saved image to data/dataset\Ascariasis\augmented\augmented_44.jpg
# ...
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_211.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_210.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_209.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_208.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_207.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_206.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_205.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_204.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_203.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_202.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_201.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_200.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_199.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_198.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_197.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_196.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_195.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_194.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_193.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_192.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_191.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_190.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_189.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_188.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_187.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_186.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_185.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_184.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_183.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_182.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_181.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_180.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_179.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_178.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_177.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_176.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_175.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_174.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_173.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_172.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_171.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_170.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_169.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_168.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_167.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_166.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_165.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_164.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_163.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_162.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_161.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_160.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_159.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_158.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_157.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_156.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_155.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_154.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_153.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_152.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_151.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_150.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_149.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_148.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_147.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_146.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_145.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_144.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_143.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_142.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_141.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_140.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_139.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_138.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_137.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_136.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_135.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_134.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_133.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_132.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_131.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_130.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_129.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_128.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_127.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_126.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_125.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_124.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_123.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_122.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_121.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_120.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_119.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_118.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_117.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_116.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_115.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_114.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_113.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_112.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_111.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_110.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_109.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_108.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_107.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_106.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_105.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_104.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_103.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_102.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_101.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_100.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_99.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_98.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_97.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_96.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_95.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_94.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_93.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_92.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_91.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_90.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_89.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_88.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_87.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_86.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_85.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_84.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_83.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_82.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_81.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_80.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_79.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_78.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_77.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_76.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_75.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_74.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_73.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_72.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_71.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_70.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_69.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_68.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_67.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_66.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_65.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_64.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_63.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_62.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_61.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_60.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_59.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_58.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_57.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_56.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_55.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_54.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_53.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_52.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_51.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_50.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_49.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_48.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_47.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_46.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_45.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_44.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_43.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_42.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_41.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_40.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_39.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_38.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_37.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_36.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_35.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_34.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_33.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_32.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_31.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_30.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_29.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_28.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_27.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_26.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_25.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_24.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_23.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_22.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_21.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_20.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_19.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_18.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_17.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_16.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_15.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_14.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_13.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_12.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_11.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_10.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_9.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_8.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_7.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_6.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_5.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_4.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_3.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_2.jpg
# Saved image to data/dataset\Trichuris trichiura\augmented\augmented_1.jpg
# Oversampling completed!

# %% [markdown]
# ## Data Under-sampling

# %%
dataset_folder = "data/dataset"
desired_samples_per_class = 608
undersampled_folder = "data/undersampled_dataset"

# %%
os.makedirs(undersampled_folder, exist_ok=True)
for label_folder in os.listdir(dataset_folder):
    label_path = os.path.join(dataset_folder, label_folder)
    if os.path.isdir(label_path):
        files = os.listdir(label_path)

        random.shuffle(files)

        selected_files = files[:desired_samples_per_class]

        undersampled_label_path = os.path.join(undersampled_folder, label_folder)
        os.makedirs(undersampled_label_path, exist_ok=True)

        for file in selected_files:
            src_file_path = os.path.join(label_path, file)
            dst_file_path = os.path.join(undersampled_label_path, file)
            shutil.copy(src_file_path, dst_file_path)

print("Undersampling complete.")
# Out:
# Undersampling complete.

# %%
path = "data/over_dataset"

# %%
dataset = []
for category in os.listdir(path):
    category_path = os.path.join(path, category)
    if os.path.isdir(category_path):
        for image_file in os.listdir(category_path):
            image_path = os.path.join(category_path, image_file)
            dataset.append((image_path, category))

# %%
random.shuffle(dataset)

# %%
train_ratio = 0.8
train_size = int(len(dataset) * train_ratio)

train_dataset = dataset[:train_size]
val_dataset = dataset[train_size:]

# %%
train_folder = 'data/train_set_oversample'
val_folder = 'data/val_set_oversample'

for image_path, category in train_dataset:
    category_folder = os.path.join(train_folder, category)
    os.makedirs(category_folder, exist_ok=True)
    shutil.copy(image_path, category_folder)

print("train done!")

for image_path, category in val_dataset:
    category_folder = os.path.join(val_folder, category)
    os.makedirs(category_folder, exist_ok=True)
    shutil.copy(image_path, category_folder)
    
print("val done!")
# Out:
# train done!
# val done!
