# %%
from Main import ParasiteDetector

# %%
detector = ParasiteDetector("train/200-epochs/weights/best.pt", 0.8)

# %%
detector.detect_parasites("data/images/test/", "d/")

# %%
detector.crop_parasites("data/images/test/", "d/")
# Out:
# 0: 384x640 1 Ascariasis, 264.3ms
# Speed: 8.0ms preprocess, 264.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Ascariasis_143.jpg Cropped and Saved!
#
# 0: 384x640 1 Ascariasis, 264.1ms
# Speed: 8.0ms preprocess, 264.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Ascariasis_145.jpg Cropped and Saved!
#
# 0: 640x480 1 Ascariasis, 364.4ms
# Speed: 8.0ms preprocess, 364.4ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 480)
# Ascariasis_197.jpg Cropped and Saved!
#
# 0: 640x608 1 Ascariasis, 512.4ms
# Speed: 24.0ms preprocess, 512.4ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 608)
# Ascariasis_225.jpg Cropped and Saved!
#
# 0: 256x640 1 Ascariasis, 328.3ms
# Speed: 12.0ms preprocess, 328.3ms inference, 4.0ms postprocess per image at shape (1, 3, 256, 640)
# Ascariasis_292.jpg Cropped and Saved!
#
# 0: 608x640 1 Ascariasis, 416.4ms
# ...
