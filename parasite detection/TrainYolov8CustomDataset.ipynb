# %%
### 1. Mount Google Drive ###

from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
### 2. Define root directory ###

ROOT_DIR = '/content/gdrive/MyDrive/Parasite-Detection'

# %%
### 3. Install Ultralytics ###

# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 660.4/660.4 kB 3.7 MB/s eta 0:00:00
# ...

# %%
### 4. Train model ###

import os

from ultralytics import YOLO


# Load a model
model = YOLO("yolov8n.pt")  # load pre trained model

# Use the model
results = model.train(data=os.path.join(ROOT_DIR, "config.yaml"), epochs=50)  # train the model
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 75.1MB/s]
# Ultralytics YOLOv8.0.226 🚀 Python-3.10.12 torch-2.1.0+cu118 CPU (Intel Xeon 2.20GHz)
# ...

# %%
import shutil

# Source directory
source_dir = "/content/runs/detect/train"

# Destination directory in Google Drive
destination_dir = "/content/gdrive/MyDrive/Parasite-Detection/train-50epoch"

# Copy files
shutil.copytree(source_dir, destination_dir)
# Out:
# '/content/gdrive/MyDrive/Parasite-Detection/train-50epoch'
